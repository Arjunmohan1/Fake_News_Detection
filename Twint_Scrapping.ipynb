# %% [markdown]
# <a href="https://colab.research.google.com/github/Arjunmohan1/Fake_News_Detection/blob/main/Twint_Scrapping.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Cell 1
# !pip install nest_asyncio
#Cell 2
# !pip install twint
#Cell 3
from google.colab import drive
drive.mount('/content/drive') #PASTE CODE GENERATED BY GOING TO GIVEN URL AND SELECTING YOUR GOOGLE DRIVE ACCOUNT WHERE DATASETS ARE UPLOADED
#Cell 4
import pandas as pd
#Cell 5
#UPLOAD THE DATASETS TO YOUR DRIVE FIRST 
path = "/content/drive/My Drive/Internship/fakenews.csv" #CHANGE THE PATH AND NAME ACCORDING TO YOUR DRIVE AND DATASET USED RESPECTIVELY
fakenews = pd.read_csv(path)
path = "/content/drive/My Drive/Internship/realnews.csv" #CHANGE THE PATH AND NAME ACCORDING TO YOUR DRIVE AND DATASET USED RESPECTIVELY
realnews = pd.read_csv(path)
#Cell 6
import nest_asyncio
import twint
#Cell 7
nest_asyncio.apply()
#Cell 8
columns = ["headline"]
faketweets = pd.DataFrame(columns=columns) #TO STORE THE SCRAPPED FAKE NEWS TWEETS
#Cell 9
n = len(fakenews.index)
#Cell 10
faketweets=faketweets.drop(faketweets.index[:]) #ONLY USE WHEN YOU WANT TO CLEAR ALL ROWS FROM THE DATASET
#Cell 11
for i in range(10000): #LOOP USED TO COLLECT TWEETS FOR FIRST 10000 HEADLINES(YOU CAN CHANGE THE RANGE TO GET TWEETS AS PER YOUR REQUIREMENTS)
  #configuration
  config = twint.Config()
  config.Search = fakenews.iloc[i,0] #TAKE iTH HEADLINE FROM THE FAKE NEWS DATASET 
  config.Limit = 20 #GETS A MAXIMUM OF 20 TWEETS
  config.Pandas = True
  config.Stats = True
  config.Count = True
  config.Filter_retweets = True #SET TO TRUE IF YOU WANT TO REMOVE RETWEETS
  #config.Min_likes = 1
  #config.Min_retweets = 1
 
  #running search
  twint.run.Search(config)
  Tweets = twint.storage.panda.Tweets_df #STORES THE SCRAPPED FAKE NEWS TWEETS
  print("Headline:",i)
  faketweets = faketweets.append(Tweets,ignore_index = True) #ADDS FAKE NEWS TWEETS TO THE FAKETWEETS DATASET
# Out:
# ...
#      |████████████████████████████████| 1.2MB 4.8MB/s
# ...
#      |████████████████████████████████| 245kB 13.2MB/s
# ...
#      |████████████████████████████████| 102kB 7.7MB/s
# ...
#      |████████████████████████████████| 256kB 13.8MB/s
# ...
#      |████████████████████████████████| 153kB 13.3MB/s
# ...
#      |████████████████████████████████| 235kB 14.6MB/s
# ...
#   Created wheel for twint: filename=twint-2.1.20-cp36-none-any.whl size=33921 sha256=16c4a21063b5349720311bb3fb73ec943dbb71f0c8050e3a4b74be321fa678f5
#   Stored in directory: /root/.cache/pip/wheels/66/25/c7/855c1d896087ef84df6e6713b8adb073aff99af119450e1e4f
# ...
#   Created wheel for fake-useragent: filename=fake_useragent-0.1.11-cp36-none-any.whl size=13484 sha256=650dda154d417793121f4349403b4047ee4c61472865d1834dd1c565d038ba1a
#   Stored in directory: /root/.cache/pip/wheels/5e/63/09/d1dc15179f175357d3f5c00cbffbac37f9e8690d80545143ff
# ...
